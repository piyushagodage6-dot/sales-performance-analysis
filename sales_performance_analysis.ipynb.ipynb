# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding='latin1')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# - Handled encoding issues while loading the dataset using latin1 encoding

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Order Date'].dtype
# Out:
# dtype('O')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')

# %%
df['Order Month'] = df['Order Date'].dt.to_period('M')

# %%
df[['Order Date', 'Order Month']].head()
# Out:
#   Order Date Order Month
# 0 2016-11-08     2016-11
# 1 2016-11-08     2016-11
# 2 2016-06-12     2016-06
# 3 2015-10-11     2015-10
# 4 2015-10-11     2015-10

# %%
monthly_sales = df.groupby('Order Month')['Sales'].sum()
monthly_sales
# Out:
# Order Month
# 2014-01     14236.8950
# 2014-02      4519.8920
# 2014-03     55691.0090
# 2014-04     28295.3450
# 2014-05     23648.2870
# 2014-06     34595.1276
# 2014-07     33946.3930
# 2014-08     27909.4685
# 2014-09     81777.3508
# 2014-10     31453.3930
# 2014-11     78628.7167
# 2014-12     69545.6205
# 2015-01     18174.0756
# 2015-02     11951.4110
# 2015-03     38726.2520
# 2015-04     34195.2085
# 2015-05     30131.6865
# 2015-06     24797.2920
# 2015-07     28765.3250
# 2015-08     36898.3322
# 2015-09     64595.9180
# 2015-10     31404.9235
# 2015-11     75972.5635
# 2015-12     74919.5212
# 2016-01     18542.4910
# 2016-02     22978.8150
# 2016-03     51715.8750
# 2016-04     38750.0390
# 2016-05     56987.7280
# 2016-06     40344.5340
# 2016-07     39261.9630
# 2016-08     31115.3743
# 2016-09     73410.0249
# 2016-10     59687.7450
# 2016-11     79411.9658
# 2016-12     96999.0430
# 2017-01     43971.3740
# 2017-02     20301.1334
# 2017-03     58872.3528
# ...

# %%
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
category_sales
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
category_profit = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
category_profit
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %% [markdown]
# ## Day 2 – Sales & Profit Analysis
#
# - Created monthly sales trends to analyze business growth over time
# - Performed category-wise sales and profit analysis
# - Identified high-sales and profit-contributing categories

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Order Month'],
#       dtype='object')

# %%
segment_perf = df.groupby('Segment')[['Sales','Profit']].sum()
segment_perf
# Out:
#                     Sales       Profit
# Segment
# Consumer     1.161401e+06  134119.2092
# Corporate    7.061464e+05   91979.1340
# Home Office  4.296531e+05   60298.6785

# %%
segment_perf['Sales'].plot(kind='bar')
plt.title("Sales by Customer Segment")
plt.xlabel("Segment")
plt.ylabel("Total Sales")
plt.show()

# %%
segment_perf['Profit'].plot(kind='bar')
plt.title("Profit by Customer Segment")
plt.xlabel("Segment")
plt.ylabel("Total Profit")
plt.show()

# %%
region_perf = df.groupby('Region')[['Sales','Profit']].sum()
region_perf
# Out:
#                Sales       Profit
# Region
# Central  501239.8908   39706.3625
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# West     725457.8245  108418.4489

# %%
region_perf['Profit'].plot(kind='bar')
plt.title("Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")
plt.show()

# %%
region_perf[region_perf['Profit'] < 0]
# Out:
# Empty DataFrame
# Columns: [Sales, Profit]
# Index: []

# %% [markdown]
# ## Day 3 – Customer Segment & Region Insights
#
# - Analyzed customer segment-wise sales and profit performance
# - Identified profitable and low-performing customer segments
# - Performed region-wise profit analysis to detect loss-making regions

# %%
monthly_sales = df.groupby('Order Month')['Sales'].sum()

plt.figure()
monthly_sales.plot()
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

plt.figure()
category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
region_profit = df.groupby('Region')['Profit'].sum().sort_values()

plt.figure()
region_profit.plot(kind='bar')
plt.title("Profit by Region")
plt.xlabel("Region")
plt.ylabel("Total Profit")
plt.show()

# %%
loss_subcat = df.groupby('Sub-Category')['Profit'].sum().sort_values().head(10)
loss_subcat
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Name: Profit, dtype: float64

# %%
plt.figure()
loss_subcat.plot(kind='bar')
plt.title("Top 10 Loss-making Sub-Categories")
plt.xlabel("Sub-Category")
plt.ylabel("Total Loss")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Day 4 – Visualization & Advanced Insights
#
# - Visualized monthly sales trends using line charts
# - Created category-wise and region-wise performance bar charts
# - Identified top loss-making sub-categories to highlight improvement areas

# %% [markdown]
# ## Final Insights & Conclusion
#
# - Technology category contributes the highest sales but shows fluctuating profit trends
# - Certain sub-categories consistently generate losses, indicating pricing or cost issues
# - Customer segments and regions show varied profitability patterns
# - Time-based sales analysis helps in identifying seasonal trends
#
# This project demonstrates the use of Python for real-world sales data analysis,
# including data cleaning, exploratory analysis, visualization, and business insights.
